# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('C:\\Users\\lenovo\\Desktop\\Bla\\MI.csv' , na_values=['?', 'UNDEFINED'])

# %%
data
# Out:
#        age     sex        bmi smoker     region children      expenses
# 0     21.0    male  25.745000     no  northeast      two   3279.868550
# 1     37.0  female  25.744165    yes  southeast    three  21454.494240
# 2     18.0    male  30.030000     no  southeast      one           NaN
# 3     37.0    male  30.676891     no  northeast    three   6801.437542
# 4     58.0    male  32.010000     no  southeast      one  11946.625900
# ...    ...     ...        ...    ...        ...      ...           ...
# 3625  49.0  female  41.426984     no  northwest     four  10987.324960
# 3626  39.0  female  26.202557     no  southeast      two  11735.844350
# 3627  56.0    male  40.300000     no  southwest     zero  10602.385000
# 3628  48.0  female  34.930624     no  southeast      one   8976.140452
# 3629  38.0  female  25.219233     no  northeast    three   7027.698968
#
# [3630 rows x 7 columns]

# %%
data.dtypes
# Out:
# age         float64
# sex          object
# bmi         float64
# smoker       object
# region       object
# children     object
# expenses    float64
# dtype: object

# %%
data.isnull()
# Out:
#         age    sex    bmi  smoker  region  children  expenses
# 0     False  False  False   False   False     False     False
# 1     False  False  False   False   False     False     False
# 2     False  False  False   False   False     False      True
# 3     False  False  False   False   False     False     False
# 4     False  False  False   False   False     False     False
# ...     ...    ...    ...     ...     ...       ...       ...
# 3625  False  False  False   False   False     False     False
# 3626  False  False  False   False   False     False     False
# 3627  False  False  False   False   False     False     False
# 3628  False  False  False   False   False     False     False
# 3629  False  False  False   False   False     False     False
#
# [3630 rows x 7 columns]

# %%
mask = data.isnull().any(axis=1)
data[mask]
# Out:
#        age     sex        bmi smoker     region children      expenses
# 2     18.0    male  30.030000     no  southeast      one           NaN
# 5     46.0    male        NaN     no  southeast      one   7742.109800
# 6      NaN    male  31.192647     no  northeast     four  21736.328140
# 14    22.0     NaN  27.045185     no  northeast     four  18091.373810
# 19    29.0    male  32.110000     no        NaN      two   4433.915900
# ...    ...     ...        ...    ...        ...      ...           ...
# 3357  23.0     NaN  25.617919    yes  northwest      two  23033.884030
# 3370  35.0  female  27.783813     no  southeast    three           NaN
# 3539  25.0     NaN        NaN     no  northeast     zero   3213.622050
# 3540  49.0     NaN  36.955080     no  northwest     four  11184.493890
# 3615  37.0    male  20.688197     no        NaN    three   6673.000573
#
# [78 rows x 7 columns]

# %%
mask = data.isnull().any(axis=1)
data[~mask]
# Out:
#        age     sex        bmi smoker     region children      expenses
# 0     21.0    male  25.745000     no  northeast      two   3279.868550
# 1     37.0  female  25.744165    yes  southeast    three  21454.494240
# 3     37.0    male  30.676891     no  northeast    three   6801.437542
# 4     58.0    male  32.010000     no  southeast      one  11946.625900
# 7     29.0  female  24.222614     no  northwest      two   4916.953065
# ...    ...     ...        ...    ...        ...      ...           ...
# 3625  49.0  female  41.426984     no  northwest     four  10987.324960
# 3626  39.0  female  26.202557     no  southeast      two  11735.844350
# 3627  56.0    male  40.300000     no  southwest     zero  10602.385000
# 3628  48.0  female  34.930624     no  southeast      one   8976.140452
# 3629  38.0  female  25.219233     no  northeast    three   7027.698968
#
# [3552 rows x 7 columns]

# %%
data.isnull().sum().sum()
# Out:
# 84

# %%
data
mask = data.isnull().any(axis=1)
no_of_rows_with_nan = mask.sum()
total_no_of_rows = len(data)

no_of_rows_with_nan / total_no_of_rows
# Out:
# 0.021487603305785124

# %%
data.isnull().sum()
# Out:
# age         13
# sex         13
# bmi         12
# smoker       8
# region      10
# children     7
# expenses    21
# dtype: int64

# %%
data2 = data.dropna()
data2
# Out:
#        age     sex        bmi smoker     region children      expenses
# 0     21.0    male  25.745000     no  northeast      two   3279.868550
# 1     37.0  female  25.744165    yes  southeast    three  21454.494240
# 3     37.0    male  30.676891     no  northeast    three   6801.437542
# 4     58.0    male  32.010000     no  southeast      one  11946.625900
# 7     29.0  female  24.222614     no  northwest      two   4916.953065
# ...    ...     ...        ...    ...        ...      ...           ...
# 3625  49.0  female  41.426984     no  northwest     four  10987.324960
# 3626  39.0  female  26.202557     no  southeast      two  11735.844350
# 3627  56.0    male  40.300000     no  southwest     zero  10602.385000
# 3628  48.0  female  34.930624     no  southeast      one   8976.140452
# 3629  38.0  female  25.219233     no  northeast    three   7027.698968
#
# [3552 rows x 7 columns]

# %%
data2.describe()
# Out:
#                age          bmi      expenses
# count  3552.000000  3552.000000   3552.000000
# mean     38.879786    30.610781  12776.361166
# std      12.161331     5.433791  10745.027641
# min      18.000000    15.960000   1121.873900
# 25%      29.000000    26.681147   5645.523421
# 50%      39.000000    30.189916   9446.674130
# 75%      48.000000    34.095212  14655.883815
# max      64.000000    53.130000  63770.428010

# %%
# Create a boxplot and customize its aesthetics
boxplot = plt.boxplot(data2['age'], patch_artist=True, whiskerprops={'linewidth': 1.5}, capprops={'linewidth': 1.5}, medianprops={'linewidth': 2}, flierprops={'marker': 'o', 'markerfacecolor': 'red', 'markersize': 6})

# Set the colors for the boxplot elements
colors = ['lightblue']
for patch in boxplot['boxes']:
    patch.set_facecolor(colors[0])

# Adjust the appearance of the outliers
for flier in boxplot['fliers']:
    flier.set(marker='o', color='red', alpha=1)

# Add a legend
plt.legend([boxplot['fliers'][0]], ['Outliers'])

# Show the plot
plt.show()

# %%
# Create a boxplot and customize its aesthetics
boxplot = plt.boxplot(data2['bmi'], patch_artist=True, whiskerprops={'linewidth': 1.5}, capprops={'linewidth': 1.5}, medianprops={'linewidth': 2}, flierprops={'marker': 'o', 'markerfacecolor': 'red', 'markersize': 6})

# Set the colors for the boxplot elements
colors = ['lightblue']
for patch in boxplot['boxes']:
    patch.set_facecolor(colors[0])

# Adjust the appearance of the outliers
for flier in boxplot['fliers']:
    flier.set(marker='o', color='red', alpha=1)

# Add a legend
plt.legend([boxplot['fliers'][0]], ['Outliers'])

# Show the plot
plt.show()

# %%
plt.boxplot(data2['bmi'], sym='')
plt.show()

Q1 = data2['bmi'].quantile(0.25)
Q3 = data2['bmi'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the DataFrame to exclude outliers
data_filtered = data2[(data2['bmi'] >= lower_bound) & (data2['bmi'] <= upper_bound)]

# Display the resulting DataFrame without outliers
print(data_filtered)
# Out:
#        age     sex        bmi smoker     region children      expenses
# 0     21.0    male  25.745000     no  northeast      two   3279.868550
# 1     37.0  female  25.744165    yes  southeast    three  21454.494240
# 3     37.0    male  30.676891     no  northeast    three   6801.437542
# 4     58.0    male  32.010000     no  southeast      one  11946.625900
# 7     29.0  female  24.222614     no  northwest      two   4916.953065
# ...    ...     ...        ...    ...        ...      ...           ...
# 3625  49.0  female  41.426984     no  northwest     four  10987.324960
# 3626  39.0  female  26.202557     no  southeast      two  11735.844350
# 3627  56.0    male  40.300000     no  southwest     zero  10602.385000
# 3628  48.0  female  34.930624     no  southeast      one   8976.140452
# 3629  38.0  female  25.219233     no  northeast    three   7027.698968
#
# [3526 rows x 7 columns]

# %%
# Create a boxplot and customize its aesthetics
boxplot = plt.boxplot(data_filtered['expenses'], patch_artist=True, whiskerprops={'linewidth': 1.5}, capprops={'linewidth': 1.5}, medianprops={'linewidth': 2}, flierprops={'marker': 'o', 'markerfacecolor': 'red', 'markersize': 6})

# Set the colors for the boxplot elements
colors = ['lightblue']
for patch in boxplot['boxes']:
    patch.set_facecolor(colors[0])

# Adjust the appearance of the outliers
for flier in boxplot['fliers']:
    flier.set(marker='o', color='red', alpha=1)

# Add a legend
plt.legend([boxplot['fliers'][0]], ['Outliers'])

# Show the plot
plt.show()

# %%
plt.boxplot(data_filtered['expenses'], sym='')
plt.show()

Q1 = data_filtered['expenses'].quantile(0.25)
Q3 = data_filtered['expenses'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the DataFrame to exclude outliers
data_filtered = data_filtered[(data_filtered['expenses'] >= lower_bound) & (data_filtered['expenses'] <= upper_bound)]

# Display the resulting DataFrame without outliers
print(data_filtered)
# Out:
#        age     sex        bmi smoker     region children      expenses
# 0     21.0    male  25.745000     no  northeast      two   3279.868550
# 1     37.0  female  25.744165    yes  southeast    three  21454.494240
# 3     37.0    male  30.676891     no  northeast    three   6801.437542
# 4     58.0    male  32.010000     no  southeast      one  11946.625900
# 7     29.0  female  24.222614     no  northwest      two   4916.953065
# ...    ...     ...        ...    ...        ...      ...           ...
# 3625  49.0  female  41.426984     no  northwest     four  10987.324960
# 3626  39.0  female  26.202557     no  southeast      two  11735.844350
# 3627  56.0    male  40.300000     no  southwest     zero  10602.385000
# 3628  48.0  female  34.930624     no  southeast      one   8976.140452
# 3629  38.0  female  25.219233     no  northeast    three   7027.698968
#
# [3179 rows x 7 columns]

# %%
data_filtered
# Out:
#        age     sex        bmi smoker     region children      expenses
# 0     21.0    male  25.745000     no  northeast      two   3279.868550
# 1     37.0  female  25.744165    yes  southeast    three  21454.494240
# 3     37.0    male  30.676891     no  northeast    three   6801.437542
# 4     58.0    male  32.010000     no  southeast      one  11946.625900
# 7     29.0  female  24.222614     no  northwest      two   4916.953065
# ...    ...     ...        ...    ...        ...      ...           ...
# 3625  49.0  female  41.426984     no  northwest     four  10987.324960
# 3626  39.0  female  26.202557     no  southeast      two  11735.844350
# 3627  56.0    male  40.300000     no  southwest     zero  10602.385000
# 3628  48.0  female  34.930624     no  southeast      one   8976.140452
# 3629  38.0  female  25.219233     no  northeast    three   7027.698968
#
# [3179 rows x 7 columns]

# %%
data_filtered.dtypes
# Out:
# age         float64
# sex          object
# bmi         float64
# smoker       object
# region       object
# children     object
# expenses    float64
# dtype: object

# %%
plt.figure(figsize=(8,5))
sns.regplot(x=data_filtered.age, y=data_filtered.expenses)
# Out:
# <Axes: xlabel='age', ylabel='expenses'>

# %%
plt.figure(figsize=(8,5))
sns.regplot(x=data_filtered.bmi, y=data_filtered.expenses)
# Out:
# <Axes: xlabel='bmi', ylabel='expenses'>

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x=data_filtered.bmi, y=data_filtered.expenses, hue=data_filtered.smoker)
# Out:
# <Axes: xlabel='bmi', ylabel='expenses'>

# %%
data_encoded = pd.get_dummies(data_filtered, dtype=int)
data_encoded
# Out:
#        age        bmi      expenses  sex_female  sex_male  smoker_no  \
# 0     21.0  25.745000   3279.868550           0         1          1
# 1     37.0  25.744165  21454.494240           1         0          0
# 3     37.0  30.676891   6801.437542           0         1          1
# 4     58.0  32.010000  11946.625900           0         1          1
# 7     29.0  24.222614   4916.953065           1         0          1
# ...    ...        ...           ...         ...       ...        ...
# 3625  49.0  41.426984  10987.324960           1         0          1
# 3626  39.0  26.202557  11735.844350           1         0          1
# 3627  56.0  40.300000  10602.385000           0         1          1
# 3628  48.0  34.930624   8976.140452           1         0          1
# 3629  38.0  25.219233   7027.698968           1         0          1
#
#       smoker_yes  region_northeast  region_northwest  region_southeast  \
# ...

# %%
X = data_encoded.drop(data_encoded.columns[2], axis=1).values
y = data_encoded.iloc[:, 2:3].values

print('x',X)

print('y',y)
# Out:
# x [[21.         25.745       0.         ...  0.          1.
#    0.        ]
#  [37.         25.74416485  1.         ...  1.          0.
#    0.        ]
#  [37.         30.67689127  0.         ...  1.          0.
#    0.        ]
#  ...
#  [56.         40.3         0.         ...  0.          0.
#    1.        ]
#  [48.         34.93062394  1.         ...  0.          0.
#    0.        ]
#  [38.         25.21923327  1.         ...  1.          0.
#    0.        ]]
# y [[ 3279.86855 ]
#  [21454.49424 ]
#  [ 6801.437542]
#  ...
#  [10602.385   ]
#  [ 8976.140452]
#  [ 7027.698968]]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
y_scaled = scaler.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size = 0.2, random_state = 1)
print(X_train)
print(X_test)
print(y_train)
print(y_test)
# Out:
# [[ 1.03878457  2.04975476  1.08645483 ... -0.43201482 -0.43201482
#    2.23059721]
#  [-0.45764891 -0.64774587  1.08645483 ... -0.43201482 -0.43201482
#    2.23059721]
#  [-0.37451372 -0.12054521 -0.92042483 ... -0.43201482 -0.43201482
#   -0.44831043]
#  ...
#  [-0.87332488 -1.11036772 -0.92042483 ... -0.43201482 -0.43201482
#   -0.44831043]
#  [-1.70467682  0.26448073  1.08645483 ... -0.43201482 -0.43201482
#   -0.44831043]
#  [ 1.12191977  0.52667617 -0.92042483 ...  2.31473541 -0.43201482
#   -0.44831043]]
# [[-0.37451372 -0.60507585 -0.92042483 ... -0.43201482 -0.43201482
#   -0.44831043]
#  [-0.6239193  -0.00559884 -0.92042483 ... -0.43201482 -0.43201482
#   -0.44831043]
#  [ 0.87251419  0.37773985  1.08645483 ... -0.43201482 -0.43201482
#   -0.44831043]
#  ...
#  [ 0.04116225 -1.66290622 -0.92042483 ... -0.43201482  2.31473541
#   -0.44831043]
#  [ 1.03878457  2.53087549 -0.92042483 ... -0.43201482 -0.43201482
#   -0.44831043]
# ...

# %%
from sklearn.linear_model import LinearRegression
lg = LinearRegression()
lg.fit(X_train, y_train)
y_predict = lg.predict(X_test)

# %%
plt.scatter(X_test[:, 0], y_test, color='red', label='Actual') 
plt.scatter(X_test[:, 0], y_predict, color='blue', label='Predicted')
plt.title('Predicted vs Actual')
plt.xlabel('expenses')
plt.ylabel('age')
plt.legend()
plt.show()

# %%
plt.scatter(X_test[:, 1], y_test, color='red', label='Actual')  # Considering the first column of X_test
plt.scatter(X_test[:, 1], y_predict, color='blue', label='Predicted')
plt.title('Predicted vs Actual')
plt.xlabel('expenses')
plt.ylabel('bmi')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mae = mean_absolute_error(y_test, y_predict)
mse = mean_squared_error(y_test, y_predict)
r_squared = r2_score(y_test, y_predict)

print(f"Mean Absolute Error: {mae:.4f}\n")
print(f"Mean Squared Error: {mse:.4f}\n")
print(f"R-squared: {r_squared:.4f}\n")
# Out:
# Mean Absolute Error: 0.3835
#
# Mean Squared Error: 0.3786
#
# R-squared: 0.6390

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_val_score
import numpy as np

# Reshape y_train to a 1D array 
y_train_reshaped = np.ravel(y_train)

gb_model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, random_state=42)
cv_scores = cross_val_score(gb_model, X_train, y_train_reshaped, cv=5, scoring='r2')

print("Cross-validation R-squared scores:", cv_scores)
print(f"Mean R-squared: {cv_scores.mean():.4f}")
# Out:
# Cross-validation R-squared scores: [0.76809777 0.71482062 0.74189352 0.69885988 0.75042694]
# Mean R-squared: 0.7348
