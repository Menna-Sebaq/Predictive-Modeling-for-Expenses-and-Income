# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('C:\\Users\\lenovo\\Desktop\\Bla\\insurance.csv' , na_values=['?', 'UNDEFINED'])

# %%
data
# Out:
#        age     sex   bmi children smoker     region  expenses
# 0     19.0  female  27.9     zero    yes  southwest  16884.92
# 1      NaN    male  33.8      one     no  southeast   1725.55
# 2     28.0    male  33.0    three     no  southeast   4449.46
# 3     33.0    male  22.7     zero     no  northwest  21984.47
# 4     32.0    male  28.9     zero     no  northwest   3866.86
# ...    ...     ...   ...      ...    ...        ...       ...
# 1333  50.0    male  31.0    three     no  northwest  10600.55
# 1334  18.0  female  31.9     zero     no  northeast   2205.98
# 1335  18.0  female  36.9     zero     no  southeast   1629.83
# 1336  21.0  female  25.8     zero     no  southwest   2007.95
# 1337  61.0  female  29.1     zero    yes  northwest       NaN
#
# [1338 rows x 7 columns]

# %%
data.dtypes
# Out:
# age         float64
# sex          object
# bmi         float64
# children     object
# smoker       object
# region       object
# expenses    float64
# dtype: object

# %%
data.isnull()
# Out:
#         age    sex    bmi  children  smoker  region  expenses
# 0     False  False  False     False   False   False     False
# 1      True  False  False     False   False   False     False
# 2     False  False  False     False   False   False     False
# 3     False  False  False     False   False   False     False
# 4     False  False  False     False   False   False     False
# ...     ...    ...    ...       ...     ...     ...       ...
# 1333  False  False  False     False   False   False     False
# 1334  False  False  False     False   False   False     False
# 1335  False  False  False     False   False   False     False
# 1336  False  False  False     False   False   False     False
# 1337  False  False  False     False   False   False      True
#
# [1338 rows x 7 columns]

# %%
mask = data.isnull().any(axis=1)
data[mask]
# Out:
#        age     sex   bmi children smoker     region  expenses
# 1      NaN    male  33.8      one     no  southeast   1725.55
# 6     46.0  female  33.4      one     no  southeast       NaN
# 8     37.0    male  29.8      two    NaN  northeast   6406.41
# 16    52.0     NaN  30.8      one     no  northeast  10797.34
# 19    30.0    male  35.3      NaN    yes  southwest  36837.47
# ...    ...     ...   ...      ...    ...        ...       ...
# 1323  42.0  female   NaN      two    yes  southeast  43896.38
# 1326  42.0  female  32.9     zero    NaN        NaN   7050.02
# 1327  51.0    male  30.0      one     no  southeast       NaN
# 1328   NaN  female  24.2      two     no  northeast  22395.74
# 1337  61.0  female  29.1     zero    yes  northwest       NaN
#
# [201 rows x 7 columns]

# %%
mask = data.isnull().any(axis=1)
data[~mask]
# Out:
#        age     sex   bmi children smoker     region  expenses
# 0     19.0  female  27.9     zero    yes  southwest  16884.92
# 2     28.0    male  33.0    three     no  southeast   4449.46
# 3     33.0    male  22.7     zero     no  northwest  21984.47
# 4     32.0    male  28.9     zero     no  northwest   3866.86
# 5     31.0  female  25.7     zero     no  southeast   3756.62
# ...    ...     ...   ...      ...    ...        ...       ...
# 1332  52.0  female  44.7    three     no  southwest  11411.69
# 1333  50.0    male  31.0    three     no  northwest  10600.55
# 1334  18.0  female  31.9     zero     no  northeast   2205.98
# 1335  18.0  female  36.9     zero     no  southeast   1629.83
# 1336  21.0  female  25.8     zero     no  southwest   2007.95
#
# [1137 rows x 7 columns]

# %%
data.isnull().sum().sum()
# Out:
# 208

# %%
data
mask = data.isnull().any(axis=1)
no_of_rows_with_nan = mask.sum()
total_no_of_rows = len(data)

no_of_rows_with_nan / total_no_of_rows
# Out:
# 0.15022421524663676

# %%
data.isnull().sum() / len(data)
# Out:
# age         0.026906
# sex         0.017190
# bmi         0.015695
# children    0.020927
# smoker      0.024664
# region      0.025411
# expenses    0.024664
# dtype: float64

# %%
data.isnull().sum()
# Out:
# age         36
# sex         23
# bmi         21
# children    28
# smoker      33
# region      34
# expenses    33
# dtype: int64

# %%
data2 = data.dropna()
data2
# Out:
#        age     sex   bmi children smoker     region  expenses
# 0     19.0  female  27.9     zero    yes  southwest  16884.92
# 2     28.0    male  33.0    three     no  southeast   4449.46
# 3     33.0    male  22.7     zero     no  northwest  21984.47
# 4     32.0    male  28.9     zero     no  northwest   3866.86
# 5     31.0  female  25.7     zero     no  southeast   3756.62
# ...    ...     ...   ...      ...    ...        ...       ...
# 1332  52.0  female  44.7    three     no  southwest  11411.69
# 1333  50.0    male  31.0    three     no  northwest  10600.55
# 1334  18.0  female  31.9     zero     no  northeast   2205.98
# 1335  18.0  female  36.9     zero     no  southeast   1629.83
# 1336  21.0  female  25.8     zero     no  southwest   2007.95
#
# [1137 rows x 7 columns]

# %%
data2.describe()
# Out:
#                age           bmi      expenses
# count  1137.000000  1.137000e+03  1.137000e+03
# mean     50.505717  3.058876e+03  2.137040e+05
# std      74.584744  9.886667e+04  2.835380e+06
# min      18.000000  1.600000e+01  1.121870e+03
# 25%      27.000000  2.630000e+01  4.738270e+03
# 50%      40.000000  3.050000e+01  9.715840e+03
# 75%      52.000000  3.520000e+01  1.824650e+04
# max     848.000000  3.333339e+06  8.884571e+07

# %%
# Create a boxplot and customize its aesthetics
boxplot = plt.boxplot(data2['age'], patch_artist=True, whiskerprops={'linewidth': 1.5}, capprops={'linewidth': 1.5}, medianprops={'linewidth': 2}, flierprops={'marker': 'o', 'markerfacecolor': 'red', 'markersize': 6})

# Set the colors for the boxplot elements
colors = ['lightblue']
for patch in boxplot['boxes']:
    patch.set_facecolor(colors[0])

# Adjust the appearance of the outliers
for flier in boxplot['fliers']:
    flier.set(marker='o', color='red', alpha=1)

# Add a legend
plt.legend([boxplot['fliers'][0]], ['Outliers'])

# Show the plot
plt.show()

# %%
plt.boxplot(data2['age'], sym='')
plt.show()

Q1 = data2['age'].quantile(0.25)
Q3 = data2['age'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the DataFrame to exclude outliers
data_filtered = data2[(data2['age'] >= lower_bound) & (data2['age'] <= upper_bound)]

# Display the resulting DataFrame without outliers
print(data_filtered)
# Out:
#        age     sex   bmi children smoker     region  expenses
# 0     19.0  female  27.9     zero    yes  southwest  16884.92
# 2     28.0    male  33.0    three     no  southeast   4449.46
# 3     33.0    male  22.7     zero     no  northwest  21984.47
# 4     32.0    male  28.9     zero     no  northwest   3866.86
# 5     31.0  female  25.7     zero     no  southeast   3756.62
# ...    ...     ...   ...      ...    ...        ...       ...
# 1332  52.0  female  44.7    three     no  southwest  11411.69
# 1333  50.0    male  31.0    three     no  northwest  10600.55
# 1334  18.0  female  31.9     zero     no  northeast   2205.98
# 1335  18.0  female  36.9     zero     no  southeast   1629.83
# 1336  21.0  female  25.8     zero     no  southwest   2007.95
#
# [1105 rows x 7 columns]

# %%
# Create a boxplot and customize its aesthetics
boxplot = plt.boxplot(data_filtered['bmi'], patch_artist=True, whiskerprops={'linewidth': 1.5}, capprops={'linewidth': 1.5}, medianprops={'linewidth': 2}, flierprops={'marker': 'o', 'markerfacecolor': 'red', 'markersize': 6})

# Set the colors for the boxplot elements
colors = ['lightblue']
for patch in boxplot['boxes']:
    patch.set_facecolor(colors[0])

# Adjust the appearance of the outliers
for flier in boxplot['fliers']:
    flier.set(marker='o', color='red', alpha=1)

# Add a legend
plt.legend([boxplot['fliers'][0]], ['Outliers'])

# Show the plot
plt.show()

# %%
plt.boxplot(data_filtered['bmi'], sym='')
plt.show()

Q1 = data_filtered['bmi'].quantile(0.25)
Q3 = data_filtered['bmi'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the DataFrame to exclude outliers
data_filtered = data_filtered[(data_filtered['bmi'] >= lower_bound) & (data_filtered['bmi'] <= upper_bound)]

# Display the resulting DataFrame without outliers
print(data_filtered)
# Out:
#        age     sex   bmi children smoker     region  expenses
# 0     19.0  female  27.9     zero    yes  southwest  16884.92
# 2     28.0    male  33.0    three     no  southeast   4449.46
# 3     33.0    male  22.7     zero     no  northwest  21984.47
# 4     32.0    male  28.9     zero     no  northwest   3866.86
# 5     31.0  female  25.7     zero     no  southeast   3756.62
# ...    ...     ...   ...      ...    ...        ...       ...
# 1332  52.0  female  44.7    three     no  southwest  11411.69
# 1333  50.0    male  31.0    three     no  northwest  10600.55
# 1334  18.0  female  31.9     zero     no  northeast   2205.98
# 1335  18.0  female  36.9     zero     no  southeast   1629.83
# 1336  21.0  female  25.8     zero     no  southwest   2007.95
#
# [1088 rows x 7 columns]

# %%
# Create a boxplot and customize its aesthetics
boxplot = plt.boxplot(data_filtered['expenses'], patch_artist=True, whiskerprops={'linewidth': 1.5}, capprops={'linewidth': 1.5}, medianprops={'linewidth': 2}, flierprops={'marker': 'o', 'markerfacecolor': 'red', 'markersize': 6})

# Set the colors for the boxplot elements
colors = ['lightblue']
for patch in boxplot['boxes']:
    patch.set_facecolor(colors[0])

# Adjust the appearance of the outliers
for flier in boxplot['fliers']:
    flier.set(marker='o', color='red', alpha=1)

# Add a legend
plt.legend([boxplot['fliers'][0]], ['Outliers'])

# Show the plot
plt.show()

# %%
plt.boxplot(data_filtered['expenses'], sym='')
plt.show()

Q1 = data_filtered['expenses'].quantile(0.25)
Q3 = data_filtered['expenses'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the DataFrame to exclude outliers
data_filtered = data_filtered[(data_filtered['expenses'] >= lower_bound) & (data_filtered['expenses'] <= upper_bound)]

# Display the resulting DataFrame without outliers
print(data_filtered)
# Out:
#        age     sex   bmi children smoker     region  expenses
# 0     19.0  female  27.9     zero    yes  southwest  16884.92
# 2     28.0    male  33.0    three     no  southeast   4449.46
# 3     33.0    male  22.7     zero     no  northwest  21984.47
# 4     32.0    male  28.9     zero     no  northwest   3866.86
# 5     31.0  female  25.7     zero     no  southeast   3756.62
# ...    ...     ...   ...      ...    ...        ...       ...
# 1332  52.0  female  44.7    three     no  southwest  11411.69
# 1333  50.0    male  31.0    three     no  northwest  10600.55
# 1334  18.0  female  31.9     zero     no  northeast   2205.98
# 1335  18.0  female  36.9     zero     no  southeast   1629.83
# 1336  21.0  female  25.8     zero     no  southwest   2007.95
#
# [988 rows x 7 columns]

# %%
data_filtered
# Out:
#        age     sex   bmi children smoker     region  expenses
# 0     19.0  female  27.9     zero    yes  southwest  16884.92
# 2     28.0    male  33.0    three     no  southeast   4449.46
# 3     33.0    male  22.7     zero     no  northwest  21984.47
# 4     32.0    male  28.9     zero     no  northwest   3866.86
# 5     31.0  female  25.7     zero     no  southeast   3756.62
# ...    ...     ...   ...      ...    ...        ...       ...
# 1332  52.0  female  44.7    three     no  southwest  11411.69
# 1333  50.0    male  31.0    three     no  northwest  10600.55
# 1334  18.0  female  31.9     zero     no  northeast   2205.98
# 1335  18.0  female  36.9     zero     no  southeast   1629.83
# 1336  21.0  female  25.8     zero     no  southwest   2007.95
#
# [988 rows x 7 columns]

# %%
data_filtered.dtypes
# Out:
# age         float64
# sex          object
# bmi         float64
# children     object
# smoker       object
# region       object
# expenses    float64
# dtype: object

# %%
plt.figure(figsize=(10,5))
sns.regplot(x=data_filtered.age, y=data_filtered.expenses)
# Out:
# <Axes: xlabel='age', ylabel='expenses'>

# %%
plt.figure(figsize=(10,5))
sns.regplot(x=data_filtered.bmi, y=data_filtered.expenses)
# Out:
# <Axes: xlabel='bmi', ylabel='expenses'>

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x=data_filtered.bmi, y=data_filtered.expenses, hue=data_filtered.smoker)
# Out:
# <Axes: xlabel='bmi', ylabel='expenses'>

# %%
data_encoded = pd.get_dummies(data_filtered, dtype=int)
data_encoded
# Out:
#        age   bmi  expenses  sex_female  sex_male  children_five  \
# 0     19.0  27.9  16884.92           1         0              0
# 2     28.0  33.0   4449.46           0         1              0
# 3     33.0  22.7  21984.47           0         1              0
# 4     32.0  28.9   3866.86           0         1              0
# 5     31.0  25.7   3756.62           1         0              0
# ...    ...   ...       ...         ...       ...            ...
# 1332  52.0  44.7  11411.69           1         0              0
# 1333  50.0  31.0  10600.55           0         1              0
# 1334  18.0  31.9   2205.98           1         0              0
# 1335  18.0  36.9   1629.83           1         0              0
# 1336  21.0  25.8   2007.95           1         0              0
#
#       children_four  children_one  children_three  children_two  \
# 0                 0             0               0             0
# 2                 0             0               1             0
# 3                 0             0               0             0
# 4                 0             0               0             0
# 5                 0             0               0             0
# ...             ...           ...             ...           ...
# 1332              0             0               1             0
# 1333              0             0               1             0
# 1334              0             0               0             0
# 1335              0             0               0             0
# 1336              0             0               0             0
#
#       children_zero  smoker_no  smoker_yes  region_northeast  \
# 0                 1          0           1                 0
# 2                 0          1           0                 0
# 3                 1          1           0                 0
# 4                 1          1           0                 0
# 5                 1          1           0                 0
# ...             ...        ...         ...               ...
# 1332              0          1           0                 0
# 1333              0          1           0                 0
# 1334              1          1           0                 1
# 1335              1          1           0                 0
# 1336              1          1           0                 0
#
#       region_northwest  region_southeast  region_southwest
# 0                    0                 0                 1
# 2                    0                 1                 0
# 3                    1                 0                 0
# 4                    1                 0                 0
# 5                    0                 1                 0
# ...                ...               ...               ...
# 1332                 0                 0                 1
# 1333                 1                 0                 0
# 1334                 0                 0                 0
# 1335                 0                 1                 0
# 1336                 0                 0                 1
#
# [988 rows x 17 columns]

# %%
X = data_encoded.drop(data_encoded.columns[2], axis=1).values
y = data_encoded.iloc[:, 2:3].values

print('x',X)

print('y',y)
# Out:
# x [[19.  27.9  1.  ...  0.   0.   1. ]
#  [28.  33.   0.  ...  0.   1.   0. ]
#  [33.  22.7  0.  ...  1.   0.   0. ]
#  ...
#  [18.  31.9  1.  ...  0.   0.   0. ]
#  [18.  36.9  1.  ...  0.   1.   0. ]
#  [21.  25.8  1.  ...  0.   0.   1. ]]
# y [[16884.92]
#  [ 4449.46]
#  [21984.47]
#  [ 3866.86]
#  [ 3756.62]
#  [ 7281.51]
#  [28923.14]
#  [ 2721.32]
#  [27808.73]
#  [ 1826.84]
#  [11090.72]
#  [ 1837.24]
#  [ 2395.17]
#  [10602.39]
#  [13228.85]
#  [ 4149.74]
#  [37701.88]
#  [ 6203.9 ]
#  [14451.84]
#  [12268.63]
#  [ 2775.19]
#  [35585.58]
#  [ 2198.19]
#  [ 4687.8 ]
#  [13770.1 ]
#  [ 1625.43]
#  [15612.19]
#  [ 3046.06]
#  [ 4949.76]
#  [ 6272.48]
#  [ 6313.76]
#  [20630.28]
#  [ 3556.92]
#  [12629.9 ]
#  [ 3579.83]
#  [37742.58]
#  [ 8059.68]
#  [13607.37]
#  [34303.17]
#  [23244.79]
#  [ 5989.52]
#  [ 8606.22]
#  [ 4504.66]
#  [30166.62]
#  [ 4133.64]
#  [14711.74]
#  [ 1743.21]
#  [14235.07]
#  [ 6389.38]
#  [ 5920.1 ]
#  [17663.14]
#  [16577.78]
#  [11946.63]
#  [ 7726.85]
#  [11356.66]
#  [ 3947.41]
#  [ 2755.02]
#  [ 6571.02]
#  [ 4441.21]
#  [ 7935.29]
#  [37165.16]
#  [11033.66]
#  [21098.55]
#  [11073.18]
#  [ 8026.67]
#  [11082.58]
#  [ 2026.97]
#  [10942.13]
#  [30184.94]
#  [ 5729.01]
#  [ 3766.88]
#  [12105.32]
#  [10226.28]
#  [22412.65]
#  [15820.7 ]
#  [ 6186.13]
#  [ 3645.09]
#  [21344.85]
#  [30942.19]
#  [ 5003.85]
#  [17560.38]
#  [ 2331.52]
#  [ 3877.3 ]
#  [10825.25]
#  [11881.36]
#  [ 2404.73]
#  [11488.32]
#  [19107.78]
#  [ 8601.33]
#  [ 6686.43]
#  [ 7740.34]
#  [ 1705.62]
#  [ 2257.48]
#  [ 3385.4 ]
#  [17081.08]
#  [ 9634.54]
#  [32734.19]
#  [ 6082.41]
#  [12815.44]
#  [13616.36]
#  [11163.57]
#  [ 1632.56]
#  [ 2155.68]
#  [ 1261.44]
#  [ 2045.69]
#  [27322.73]
#  [ 2166.73]
#  [27375.9 ]
#  [ 3490.55]
#  [18157.88]
#  [20745.99]
#  [ 5138.26]
#  [ 9877.61]
#  [10959.69]
#  [ 1842.52]
#  [ 5125.22]
#  [ 7789.64]
#  [ 6334.34]
#  [19964.75]
#  [ 7077.19]
#  [ 6948.7 ]
#  [21223.68]
#  [15518.18]
#  [36950.26]
#  [19749.38]
#  [36149.48]
#  [10450.55]
#  [ 5152.13]
#  [ 5028.15]
#  [10407.09]
#  [ 4830.63]
#  [ 6128.8 ]
#  [ 2719.28]
#  [13405.39]
#  [ 8116.68]
#  [ 1694.8 ]
#  [ 2855.44]
#  [ 6455.86]
#  [10436.1 ]
#  [ 8823.28]
#  [ 8538.29]
#  [11735.88]
#  [ 1631.82]
#  [ 4005.42]
#  [ 7419.48]
#  [ 3981.98]
#  [ 5325.65]
#  [ 2137.65]
#  [12044.34]
#  [ 1137.47]
#  [ 1639.56]
#  [ 5649.72]
#  [ 8516.83]
#  [ 9644.25]
#  [14901.52]
#  [ 8871.15]
#  [13012.21]
#  [37133.9 ]
#  [ 7147.11]
#  [11743.3 ]
#  [20984.09]
#  [13880.95]
#  [ 1980.07]
#  [ 8162.72]
#  [ 3537.7 ]
#  [ 5002.78]
#  [ 8520.03]
#  [ 2483.74]
#  [ 3392.98]
#  [25081.77]
#  [ 5012.47]
#  [ 5253.52]
#  [34779.62]
#  [19515.54]
#  [ 2689.5 ]
#  [24227.34]
#  [ 7358.18]
#  [ 7443.64]
#  [14001.29]
#  [ 1727.79]
#  [12333.83]
#  [ 6710.19]
#  [ 1615.77]
#  [ 4463.21]
#  [17352.68]
#  [ 7152.67]
#  [ 5354.07]
#  [ 7196.87]
#  [29523.17]
#  [24476.48]
#  [12648.7 ]
#  [ 1986.93]
#  [ 4040.56]
#  [12829.46]
#  [ 5400.98]
#  [33750.29]
#  [11837.16]
#  [17085.27]
#  [24869.84]
#  [36219.41]
#  [20463.  ]
#  [14590.63]
#  [ 7441.05]
#  [ 9282.48]
#  [ 1719.44]
#  [ 7265.7 ]
#  [ 2523.17]
#  [ 9715.84]
#  [ 2803.7 ]
#  [ 2150.47]
#  [12928.79]
#  [ 9625.92]
#  [ 7742.11]
#  [ 9432.93]
#  [25992.82]
#  [ 3172.02]
#  [ 2156.75]
#  [ 3906.13]
#  [ 1704.57]
#  [16297.85]
#  [21978.68]
#  [ 6746.74]
#  [24873.38]
#  [12265.51]
#  [ 4349.46]
#  [19442.35]
#  [20177.67]
#  [ 4151.03]
#  [11944.59]
#  [ 7749.16]
#  [ 1737.38]
#  [ 8124.41]
#  [ 9722.77]
#  [ 8835.26]
#  [10435.07]
#  [ 7421.19]
#  [24671.66]
#  [35491.64]
#  [11566.3 ]
#  [ 2866.09]
#  [ 6600.21]
#  [ 3561.89]
#  [24393.62]
#  [13429.04]
#  [11658.38]
#  [19144.58]
#  [13937.67]
#  [ 8232.64]
#  [13217.09]
#  [13981.85]
#  [10977.21]
#  [ 4890.  ]
#  [ 5478.04]
#  [ 1635.73]
#  [11830.61]
#  [ 3554.2 ]
#  [12404.88]
#  [14133.04]
#  [24603.05]
#  [ 8944.12]
#  [ 9620.33]
#  [ 1607.51]
#  [ 4751.07]
#  [13844.51]
#  [ 2597.78]
#  [ 3180.51]
#  [ 9778.35]
#  [13430.27]
#  [ 8017.06]
#  [ 3481.87]
#  [13415.04]
#  [12029.29]
#  [36085.22]
#  [ 1391.53]
#  [21659.93]
#  [27000.98]
#  [15006.58]
#  [20781.49]
#  [ 5846.92]
#  [ 8302.54]
#  [11856.41]
#  [30284.64]
#  [ 3176.82]
#  [ 4618.08]
#  [10736.87]
#  [ 2138.07]
#  [ 9290.14]
#  [ 9411.01]
#  [ 7526.71]
#  [16586.5 ]
#  [ 1631.67]
#  [ 8083.92]
#  [14692.67]
#  [10269.46]
#  [ 3260.2 ]
#  [11396.9 ]
#  [ 4185.1 ]
#  [ 8539.67]
#  [ 6652.53]
#  [ 4074.45]
#  [ 1621.34]
#  [19594.81]
#  [14455.64]
#  [ 2134.9 ]
#  [ 7345.73]
#  [ 9140.95]
#  [18608.26]
#  [14418.28]
#  [ 2727.4 ]
#  [ 8968.33]
#  [ 9788.87]
#  [ 6555.07]
#  [ 7323.73]
#  [23082.96]
#  [ 4906.41]
#  [ 5969.72]
#  [12638.2 ]
#  [ 4243.59]
#  [13919.82]
#  [ 2254.8 ]
#  [12592.53]
#  [ 2897.32]
#  [ 4738.27]
#  [37079.37]
#  [ 1149.4 ]
#  [28287.9 ]
#  [26109.33]
#  [ 7345.08]
#  [12731.  ]
#  [11454.02]
#  [ 5910.94]
#  [ 4762.33]
#  [ 7512.27]
#  [ 4032.24]
#  [ 1969.61]
#  [ 1769.53]
#  [ 4686.39]
#  [21797.  ]
#  [11881.97]
#  [11840.78]
#  [10601.41]
#  [ 7682.67]
#  [10381.48]
#  [22144.03]
#  [15230.32]
#  [11165.42]
#  [ 1632.04]
#  [19521.97]
#  [13224.69]
#  [12643.38]
#  [23288.93]
#  [ 2201.1 ]
#  [ 2497.04]
#  [ 2203.47]
#  [ 1744.47]
#  [20878.78]
#  [25382.3 ]
#  [28868.66]
#  [35147.53]
#  [ 2534.39]
#  [ 1534.3 ]
#  [ 1824.29]
#  [15555.19]
#  [ 9304.7 ]
#  [ 1622.19]
#  [ 9880.07]
#  [ 9563.03]
#  [ 4347.02]
#  [12475.35]
#  [ 1253.94]
#  [10461.98]
#  [ 1748.77]
#  [24513.09]
#  [ 2196.47]
#  [12574.05]
#  [17942.11]
#  [ 1967.02]
#  [ 4931.65]
#  [ 8027.97]
#  [ 8211.1 ]
#  [13470.86]
#  [36197.7 ]
#  [ 6837.37]
#  [22218.11]
#  [32548.34]
#  [ 5974.38]
#  [ 6796.86]
#  [ 2643.27]
#  [ 3077.1 ]
#  [ 3044.21]
#  [11455.28]
#  [11763.  ]
#  [ 2498.41]
#  [ 9361.33]
#  [ 1256.3 ]
#  [21082.16]
#  [11362.76]
#  [27724.29]
#  [ 8413.46]
#  [ 5240.77]
#  [ 3857.76]
#  [25656.58]
#  [ 3994.18]
#  [ 9866.3 ]
#  [ 5397.62]
#  [38245.59]
#  [11482.63]
#  [24059.68]
#  [ 9861.03]
#  [ 8342.91]
#  [ 1708.  ]
#  [14043.48]
#  [12925.89]
#  [19214.71]
#  [13831.12]
#  [ 6067.13]
#  [ 5972.38]
#  [ 8825.09]
#  [ 8233.1 ]
#  [27346.04]
#  [ 6196.45]
#  [ 3056.39]
#  [13887.2 ]
#  [10231.5 ]
#  [23807.24]
#  [ 3268.85]
#  [11538.42]
#  [ 3213.62]
#  [13390.56]
#  [ 3972.92]
#  [12957.12]
#  [11187.66]
#  [17878.9 ]
#  [ 3847.67]
#  [ 3935.18]
#  [ 1646.43]
#  [ 9193.84]
#  [ 2494.02]
#  [ 9058.73]
#  [ 2801.26]
#  [ 2128.43]
#  [ 6373.56]
#  [ 3761.29]
#  [ 4753.64]
#  [31620.  ]
#  [12222.9 ]
#  [ 9724.53]
#  [ 3206.49]
#  [12913.99]
#  [ 1639.56]
#  [ 6356.27]
#  [17626.24]
#  [ 3861.21]
#  [13635.64]
#  [ 5976.83]
#  [ 8428.07]
#  [15359.1 ]
#  [ 5709.16]
#  [ 7640.31]
#  [ 5594.85]
#  [ 7441.5 ]
#  [33471.97]
#  [ 1633.04]
#  [11070.54]
#  [16085.13]
#  [17468.98]
#  [ 9283.56]
#  [ 3558.62]
#  [ 8547.69]
#  [ 6571.54]
#  [ 1880.07]
#  [34439.86]
#  [10713.64]
#  [ 3659.35]
#  [ 9182.17]
#  [34617.84]
#  [ 6748.59]
#  [11326.71]
#  [10085.85]
#  [ 3366.67]
#  [ 7173.36]
#  [14410.93]
#  [24915.05]
#  [12949.16]
#  [32787.46]
#  [13143.86]
#  [ 4466.62]
#  [18806.15]
#  [10141.14]
#  [ 1712.23]
#  [12430.95]
#  [ 9800.89]
#  [ 8280.62]
#  [12244.53]
#  [24667.42]
#  [ 4058.71]
#  [26392.26]
#  [14394.4 ]
#  [ 5148.55]
#  [ 1136.4 ]
#  [ 8703.46]
#  [ 4837.58]
#  [ 4399.73]
#  [ 6185.32]
#  [ 7222.79]
#  [12485.8 ]
#  [10156.78]
#  [ 2585.27]
#  [11244.38]
#  [ 5438.75]
#  [26236.58]
#  [ 2104.11]
#  [ 8068.19]
#  [29186.48]
#  [ 3500.61]
#  [ 2020.55]
#  [ 9541.7 ]
#  [ 9504.31]
#  [ 5385.34]
#  [ 5375.04]
#  [10264.44]
#  [ 1727.54]
#  [10107.22]
#  [ 1984.45]
#  [ 2457.5 ]
#  [12146.97]
#  [ 9566.99]
#  [10848.13]
#  [ 9875.68]
#  [11264.54]
#  [ 1263.25]
#  [10106.13]
#  [ 6664.69]
#  [ 2217.6 ]
#  [19362.  ]
#  [10065.41]
#  [ 9447.25]
#  [14007.22]
#  [ 9583.89]
#  [36189.1 ]
#  [ 8604.48]
#  [18246.5 ]
#  [ 9910.36]
#  [11737.85]
#  [ 1627.28]
#  [ 3062.51]
#  [19539.24]
#  [ 1906.36]
#  [14210.54]
#  [11833.78]
#  [17128.43]
#  [ 5031.27]
#  [23065.42]
#  [ 5428.73]
#  [36307.8 ]
#  [ 2416.96]
#  [19040.88]
#  [ 3070.81]
#  [ 9095.07]
#  [11842.62]
#  [ 7050.64]
#  [14319.03]
#  [ 6933.24]
#  [11150.78]
#  [12797.21]
#  [17748.51]
#  [ 7261.74]
#  [ 6986.7 ]
#  [ 5934.38]
#  [ 9869.81]
#  [18259.22]
#  [ 1146.8 ]
#  [ 9386.16]
#  [24520.26]
#  [ 6414.18]
#  [12741.17]
#  [ 1917.32]
#  [ 5209.58]
#  [13457.96]
#  [ 5662.23]
#  [ 1252.41]
#  [21195.82]
#  [18310.74]
#  [ 4719.52]
#  [11848.14]
#  [17904.53]
#  [ 7046.72]
#  [14313.85]
#  [ 2103.08]
#  [ 1815.88]
#  [28476.73]
#  [ 2136.88]
#  [ 1131.51]
#  [ 9414.92]
#  [ 6360.99]
#  [11013.71]
#  [ 4428.89]
#  [ 5584.31]
#  [ 1877.93]
#  [ 2680.95]
#  [ 1621.88]
#  [ 8219.2 ]
#  [12523.6 ]
#  [16069.08]
#  [20773.63]
#  [13393.76]
#  [ 5266.37]
#  [ 4719.74]
#  [ 5377.46]
#  [ 7160.33]
#  [ 4402.23]
#  [ 6402.29]
#  [12622.18]
#  [ 1526.31]
#  [12323.94]
#  [10072.06]
#  [ 9872.7 ]
#  [10601.63]
#  [37270.15]
#  [14119.62]
#  [11729.68]
#  [24106.91]
#  [15817.99]
#  [18218.16]
#  [10965.45]
#  [12269.69]
#  [ 5458.05]
#  [ 8782.47]
#  [ 6600.36]
#  [ 1141.45]
#  [11576.13]
#  [13129.6 ]
#  [ 4391.65]
#  [ 8457.82]
#  [ 3392.37]
#  [ 5966.89]
#  [ 6849.03]
#  [ 8891.14]
#  [26140.36]
#  [ 6653.79]
#  [ 6282.24]
#  [ 6311.95]
#  [ 3443.06]
#  [ 2789.06]
#  [ 2585.85]
#  [19719.69]
#  [27218.44]
#  [ 1682.6 ]
#  [29330.98]
#  [ 7243.81]
#  [10422.92]
#  [13555.  ]
#  [13063.88]
#  [19798.05]
#  [ 2221.56]
#  [ 1634.57]
#  [ 8688.86]
#  [ 4661.29]
#  [ 8125.78]
#  [12644.59]
#  [ 4564.19]
#  [ 4846.92]
#  [15170.07]
#  [17496.31]
#  [ 2639.04]
#  [33732.69]
#  [14382.71]
#  [ 5257.51]
#  [ 2473.33]
#  [21774.32]
#  [13041.92]
#  [ 5245.23]
#  [13451.12]
#  [ 5488.26]
#  [ 4320.41]
#  [ 6250.44]
#  [25333.33]
#  [ 2913.57]
#  [12032.33]
#  [ 6289.75]
#  [ 2927.06]
#  [ 6238.3 ]
#  [10096.97]
#  [ 7348.14]
#  [ 4673.39]
#  [12233.83]
#  [32108.66]
#  [ 8965.8 ]
#  [ 2304.  ]
#  [ 9487.64]
#  [ 1121.87]
#  [ 9549.57]
#  [ 2217.47]
#  [ 1628.47]
#  [12982.87]
#  [11674.13]
#  [ 7160.09]
#  [ 6358.78]
#  [19933.46]
#  [11534.87]
#  [ 4527.18]
#  [20009.63]
#  [ 3875.73]
#  [12609.89]
#  [28468.92]
#  [ 2730.11]
#  [ 3353.28]
#  [14474.68]
#  [ 9500.57]
#  [26467.1 ]
#  [ 4746.34]
#  [23967.38]
#  [ 7518.03]
#  [ 3279.87]
#  [ 8596.83]
#  [10702.64]
#  [ 4992.38]
#  [ 1759.34]
#  [ 2322.62]
#  [16138.76]
#  [ 7804.16]
#  [ 2902.91]
#  [ 9704.67]
#  [ 4889.04]
#  [25517.11]
#  [ 4500.34]
#  [19199.94]
#  [16796.41]
#  [ 7624.63]
#  [ 8410.05]
#  [28340.19]
#  [ 4518.83]
#  [ 3378.91]
#  [ 7144.86]
#  [ 5484.47]
#  [ 7986.48]
#  [ 7418.52]
#  [13887.97]
#  [ 6551.75]
#  [ 5267.82]
#  [17361.77]
#  [34472.84]
#  [ 1972.95]
#  [21232.18]
#  [ 8627.54]
#  [ 4433.39]
#  [ 4438.26]
#  [24915.22]
#  [23241.47]
#  [ 9957.72]
#  [ 8269.04]
#  [18767.74]
#  [ 8765.25]
#  [ 5383.54]
#  [12124.99]
#  [ 2709.24]
#  [ 3987.93]
#  [12495.29]
#  [26018.95]
#  [35595.59]
#  [ 1711.03]
#  [ 8569.86]
#  [ 2020.18]
#  [16450.89]
#  [ 9850.43]
#  [ 6877.98]
#  [21677.28]
#  [ 4137.52]
#  [13747.87]
#  [12950.07]
#  [12094.48]
#  [37484.45]
#  [ 2250.84]
#  [22493.66]
#  [20234.85]
#  [ 1704.7 ]
#  [33475.82]
#  [ 3161.45]
#  [11394.07]
#  [21880.82]
#  [ 7325.05]
#  [ 3594.17]
#  [ 8023.14]
#  [14394.56]
#  [ 9288.03]
#  [25309.49]
#  [ 3353.47]
#  [10594.5 ]
#  [ 8277.52]
#  [17929.3 ]
#  [ 2480.98]
#  [ 1981.58]
#  [11554.22]
#  [ 5708.87]
#  [ 7045.5 ]
#  [ 5757.41]
#  [14349.85]
#  [10928.85]
#  [13974.46]
#  [12096.65]
#  [13204.29]
#  [ 4562.84]
#  [ 8551.35]
#  [34672.15]
#  [15161.53]
#  [11884.05]
#  [ 5855.9 ]
#  [ 4076.5 ]
#  [15019.76]
#  [19023.26]
#  [11353.23]
#  [11286.54]
#  [33907.55]
#  [11299.34]
#  [ 4561.19]
#  [23045.57]
#  [ 3227.12]
#  [16776.3 ]
#  [ 3471.41]
#  [11363.28]
#  [ 8988.16]
#  [10493.95]
#  [ 2904.09]
#  [11512.41]
#  [24180.93]
#  [ 5312.17]
#  [ 2396.1 ]
#  [10807.49]
#  [ 9222.4 ]
#  [36124.57]
#  [38282.75]
#  [ 5693.43]
#  [ 8347.16]
#  [18903.49]
#  [14254.61]
#  [10214.64]
#  [ 5836.52]
#  [ 1728.9 ]
#  [20709.02]
#  [ 9991.04]
#  [19673.34]
#  [11085.59]
#  [ 7623.52]
#  [ 3704.35]
#  [ 9048.03]
#  [ 7954.52]
#  [27117.99]
#  [ 6338.08]
#  [ 9630.4 ]
#  [ 2261.57]
#  [10791.96]
#  [ 5979.73]
#  [ 2203.74]
#  [12235.84]
#  [ 5630.46]
#  [11015.17]
#  [ 7228.22]
#  [14426.07]
#  [ 2459.72]
#  [ 3989.84]
#  [ 5124.19]
#  [18963.17]
#  [ 2200.83]
#  [ 5227.99]
#  [ 4529.48]
#  [ 4670.64]
#  [ 6112.35]
#  [22478.6 ]
#  [ 6457.84]
#  [ 4433.92]
#  [ 2154.36]
#  [23887.66]
#  [19350.37]
#  [ 7650.77]
#  [ 2850.68]
#  [ 2632.99]
#  [ 9447.38]
#  [37465.34]
#  [13844.8 ]
#  [21771.34]
#  [13126.68]
#  [ 5327.4 ]
#  [13019.16]
#  [ 8671.19]
#  [ 4134.08]
#  [18838.7 ]
#  [33307.55]
#  [ 6393.6 ]
#  [ 4934.71]
#  [ 8733.23]
#  [ 2055.32]
#  [18223.45]
#  [ 5116.5 ]
#  [36910.61]
#  [20296.86]
#  [23563.02]
#  [ 1702.46]
#  [10806.84]
#  [ 3956.07]
#  [12890.06]
#  [ 5415.66]
#  [ 4058.12]
#  [ 7537.16]
#  [ 4718.2 ]
#  [ 8442.67]
#  [ 6858.48]
#  [ 4795.66]
#  [ 7162.01]
#  [10594.23]
#  [20167.34]
#  [12479.71]
#  [11345.52]
#  [ 8515.76]
#  [ 2699.57]
#  [12224.35]
#  [ 6985.51]
#  [ 3238.44]
#  [ 4296.27]
#  [ 3171.61]
#  [ 1135.94]
#  [ 5615.37]
#  [ 9101.8 ]
#  [37607.53]
#  [ 1241.57]
#  [15828.82]
#  [ 4415.16]
#  [ 6474.01]
#  [11436.74]
#  [11305.93]
#  [30063.58]
#  [10197.77]
#  [ 4544.23]
#  [ 3277.16]
#  [ 6770.19]
#  [ 7337.75]
#  [26926.51]
#  [10704.47]
#  [34254.05]
#  [ 1880.49]
#  [ 8615.3 ]
#  [ 3292.53]
#  [ 3021.81]
#  [14478.33]
#  [ 4747.05]
#  [17043.34]
#  [10959.33]
#  [ 2741.95]
#  [ 4357.04]
#  [ 4189.11]
#  [ 8283.68]
#  [24535.7 ]
#  [ 1720.35]
#  [ 3732.63]
#  [ 5472.45]
#  [ 7133.9 ]
#  [34828.65]
#  [ 1515.34]
#  [ 9301.89]
#  [11931.13]
#  [ 4340.44]
#  [ 5261.47]
#  [ 2710.83]
#  [ 3208.79]
#  [37829.72]
#  [21259.38]
#  [ 2464.62]
#  [16115.3 ]
#  [21472.48]
#  [33900.65]
#  [ 6875.96]
#  [ 6940.91]
#  [ 4536.26]
#  [11272.33]
#  [ 1731.68]
#  [ 7201.7 ]
#  [ 5425.02]
#  [28101.33]
#  [12981.35]
#  [ 4239.89]
#  [13143.34]
#  [10325.21]
#  [12629.17]
#  [10795.94]
#  [11411.69]
#  [10600.55]
#  [ 2205.98]
#  [ 1629.83]
#  [ 2007.95]]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
y_scaled = scaler.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size = 0.2, random_state = 1)
print(X_train)
print(X_test)
print(y_train)
print(y_test)
# Out:
# [[ 1.5838565   1.5049036   0.9839347  ... -0.56176439 -0.60385502
#    1.68652245]
#  [-0.68076032 -1.3020591  -1.01632761 ... -0.56176439 -0.60385502
#   -0.59293607]
#  [-1.0346067   0.30433522 -1.01632761 ... -0.56176439  1.65602664
#   -0.59293607]
#  ...
#  [ 1.23001012  0.71016115 -1.01632761 ... -0.56176439  1.65602664
#   -0.59293607]
#  [ 0.38077881 -0.43967899  0.9839347  ...  1.78010572 -0.60385502
#   -0.59293607]
#  [ 1.07293378e+00]
#  [-4.71887748e-01]
#  [ 6.08376720e-02]
#  [-5.67425627e-01]
#  [-7.33279655e-01]
#  [ 2.68187360e-01]
#  [-5.81903684e-01]
#  [ 1.98479537e+00]
#  [ 3.88791478e-02]
#  [-9.44454926e-01]
#  [-7.47652486e-01]
#  [-1.00730464e+00]
#  [ 9.65154510e-02]
#  [ 1.22586010e-01]
#  [ 1.82793357e+00]
#  [ 1.12594126e+00]
#  [ 2.95998605e+00]
#  [ 1.28405060e-01]
#  [-9.58722530e-01]
#  [-9.50938075e-01]
#  [ 3.50549656e-01]
#  [-2.79461579e-01]
#  [-8.74484856e-01]
#  [ 1.60031133e+00]
#  [-8.91400672e-01]
#  [-9.93970048e-01]
#  [-6.89608136e-01]
#  [-1.91635666e-01]
#  [ 1.29978788e-01]
#  [-6.31847898e-01]
#  [-2.90628496e-01]
#  [-5.51919852e-01]
#  [ 1.26588491e+00]
#  [-6.30676372e-01]
#  [ 7.98584926e-01]
#  [-1.03425911e+00]
#  [ 1.18701967e-01]
#  [-8.49717929e-02]
#  [ 2.47431930e-01]
#  [ 2.67947558e+00]
#  [ 1.60999104e+00]
#  [-8.13422831e-01]
#  [-3.23245340e-01]
#  [ 2.06198401e+00]
#  [ 1.42789231e+00]
#  [ 1.27891084e+00]
#  [-1.04239782e+00]
#  [ 1.01591714e+00]
#  [-4.19630880e-01]
#  [-1.08939685e+00]
#  [ 1.05806990e-01]
#  [-7.37256064e-01]
#  [ 1.68738560e-02]
#  [ 1.17841444e-01]
#  [-8.51015741e-01]
#  [-6.92916938e-01]]

# %%
from sklearn.linear_model import LinearRegression
lg = LinearRegression()
lg.fit(X_train, y_train)
y_predict = lg.predict(X_test)

# %%
plt.scatter(X_test[:, 0], y_test, color='red', label='Actual')  # Considering the first column of X_test
plt.scatter(X_test[:, 0], y_predict, color='blue', label='Predicted')
plt.title('Predicted vs Actual')
plt.xlabel('expenses')
plt.ylabel('age')
plt.legend()
plt.show()

# %%
plt.scatter(X_test[:, 1], y_test, color='red', label='Actual')  # Considering the first column of X_test
plt.scatter(X_test[:, 1], y_predict, color='blue', label='Predicted')
plt.title('Predicted vs Actual')
plt.xlabel('expenses')
plt.ylabel('bmi')
plt.legend()
plt.show()

# %%
plt.scatter(X_test[:, 2], y_test, color='red', label='Actual')  # Considering the first column of X_test
plt.scatter(X_test[:, 2], y_predict, color='blue', label='Predicted')
plt.title('Predicted vs Actual')
plt.xlabel('expenses')
plt.ylabel('female sex')
plt.legend()
plt.show()

# %%
plt.scatter(X_test[:, 3], y_test, color='red', label='Actual')  # Considering the first column of X_test
plt.scatter(X_test[:, 3], y_predict, color='blue', label='Predicted')
plt.title('Predicted vs Actual')
plt.xlabel('expenses')
plt.ylabel('male sex')
plt.legend()
plt.show()

# %%
plt.scatter(X_test[:, 4], y_test, color='red', label='Actual')  # Considering the first column of X_test
plt.scatter(X_test[:, 4], y_predict, color='blue', label='Predicted')
plt.title('Predicted vs Actual')
plt.xlabel('expenses')
plt.ylabel('five children')
plt.legend()
plt.show()

# %%
plt.scatter(X_test[:, 10], y_test, color='red', label='Actual')  # Considering the first column of X_test
plt.scatter(X_test[:, 10], y_predict, color='blue', label='Predicted')
plt.title('Predicted vs Actual')
plt.xlabel('expenses')
plt.ylabel('non smoker')
plt.legend()
plt.show()

# %%
plt.scatter(X_test[:, 11], y_test, color='red', label='Actual')  # Considering the first column of X_test
plt.scatter(X_test[:, 11], y_predict, color='blue', label='Predicted')
plt.title('Predicted vs Actual')
plt.xlabel('expenses')
plt.ylabel('smoker')
plt.legend()
plt.show()

# %%
plt.scatter(X_test[:, 12], y_test, color='red', label='Actual')  # Considering the first column of X_test
plt.scatter(X_test[:, 12], y_predict, color='blue', label='Predicted')
plt.title('Predicted vs Actual')
plt.xlabel('expenses')
plt.ylabel('northeast region')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mae = mean_absolute_error(y_test, y_predict)
mse = mean_squared_error(y_test, y_predict)
r_squared = r2_score(y_test, y_predict)

print(f"Mean Absolute Error: {mae:.4f}\n")
print(f"Mean Squared Error: {mse:.4f}\n")
print(f"R-squared: {r_squared:.4f}\n")
# Out:
# Mean Absolute Error: 0.4695
#
# Mean Squared Error: 0.5058
#
# R-squared: 0.5107

# %%
print(y_predict)
# Out:
# [[ 1.87322143e+00]
#  [-3.65059815e-01]
#  [ 2.75565185e-01]
#  [ 1.03690185e-01]
#  [-4.90059815e-01]
#  [-4.99825440e-01]
#  [-4.43184815e-01]
#  [ 2.95096435e-01]
#  [-6.91231690e-01]
#  [-8.80684815e-01]
#  [ 1.97440185e-01]
#  [ 5.80252685e-01]
#  [-5.23262940e-01]
#  [ 5.48620599e-02]
#  [-3.49434815e-01]
#  [ 6.09549560e-01]
#  [-7.63497315e-01]
#  [-8.49434815e-01]
#  [ 1.27127685e-01]
#  [-1.38497315e-01]
#  [-8.29903565e-01]
#  [ 1.50565185e-01]
#  [-8.96691901e-02]
#  [-2.10762940e-01]
#  [-7.55684815e-01]
#  [-6.56075440e-01]
#  [-2.94747315e-01]
#  [-2.40059815e-01]
#  [-5.75997315e-01]
#  [-2.08809815e-01]
#  [-5.99434815e-01]
#  [-2.24434815e-01]
#  [ 2.05681518e+00]
#  [-2.08809815e-01]
#  [ 4.11901849e-02]
#  [ 3.38065185e-01]
#  [-3.65059815e-01]
#  [ 1.65056518e+00]
#  [-3.16231690e-01]
#  [ 1.68143310e-01]
#  [-2.43966065e-01]
#  [-5.21309815e-01]
#  [-9.11934815e-01]
#  [-5.21309815e-01]
#  [ 2.18181518e+00]
#  [ 1.03690185e-01]
#  [-4.43184815e-01]
#  [-3.25997315e-01]
#  [-5.21309815e-01]
#  [ 1.34940185e-01]
#  [ 1.03690185e-01]
#  [ 3.69315185e-01]
#  [ 2.13065185e-01]
#  [ 1.35369018e+00]
#  [ 1.34940185e-01]
#  [-8.02559815e-01]
#  [-6.17012940e-01]
#  [ 5.52908935e-01]
#  [-1.85372315e-01]
#  [-8.72872315e-01]
#  [ 1.90837768e+00]
#  [ 1.11150268e+00]
#  [-9.35372315e-01]
#  [-5.99434815e-01]
#  [-2.63497315e-01]
#  [ 3.84940185e-01]
#  [-2.16622315e-01]
#  [ 2.20877685e-01]
#  [-3.41622315e-01]
#  [ 1.74431518e+00]
#  [-1.74035651e-02]
#  [ 1.35759643e+00]
#  [-5.64278565e-01]
#  [ 2.91190185e-01]
#  [ 6.03393492e-03]
#  [ 3.96658935e-01]
#  [ 1.31951050e+00]
#  [-3.10372315e-01]
#  [-2.32247315e-01]
#  [-5.68481508e-03]
#  [ 1.50565185e-01]
#  [ 8.80651849e-02]
#  [ 1.67400268e+00]
#  [-5.93575440e-01]
#  [ 1.50798706e+00]
#  [-2.55684815e-01]
#  [-9.66622315e-01]
#  [-4.43184815e-01]
#  [-5.68184815e-01]
#  [ 3.84940185e-01]
#  [ 9.58776849e-02]
#  [-7.59591065e-01]
#  [-6.85372315e-01]]

# %%
import numpy as np

y = np.array(y).reshape(-1)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (790, 16) (790, 1)
# (198, 16) (198, 1)

# %%
from sklearn.model_selection import cross_val_score

gb_model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, random_state=42)

cv_scores = cross_val_score(gb_model, X_selected, y, cv=5, scoring='r2')

print("Cross-validation R-squared scores:", cv_scores)
print(f"Mean R-squared: {cv_scores.mean():.4f}")
# Out:
# Cross-validation R-squared scores: [0.689723   0.67974341 0.55769567 0.71643404 0.67543245]
# Mean R-squared: 0.6638
